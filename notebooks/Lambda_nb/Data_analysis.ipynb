# %% [markdown]
# # Data Analysis for all combinations of n-substituents [6]Helicenes
# This notebook provides a structured workflow to obtain all the predictions for halogenated [6]Helicenes from 1 up to 6 substituents, and up to 16 due to the computational cost will just predict 100 random molecules for each substituents.

# %% [markdown]
# # Check for GPU usage

# %%
import tensorflow as tf
# Check TensorFlow version for compatibility
print("TensorFlow version:", tf.__version__)
# List available GPUs for GPU acceleration
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    print("GPUs:", physical_devices)
    try:
        # Enable dynamic memory growth (best practice to avoid GPU memory errors)
        tf.config.experimental.set_memory_growth(physical_devices[0], True)
    except Exception as e:
        pass
else:
    print("No GPU found, using CPU.")
# Out:
# TensorFlow version: 2.10.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Load data, our models and import libraries
# Load x_data and y_data as well as OHE variables and stats like mean and std Imin values from Load_manipulate notebook, as well as our model and it's upper and lower models aplications for obtaining the uncertainty intervals.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the CSV file
data_combined = pd.read_csv('OHE_data.csv')

# Separate x_data and y_data
x_data = data_combined.iloc[:, :-1].values  # All columns except the last one
y_data = data_combined['target'].values    # The last column

# Load trained and tested x_data and y_data
x_train = pd.read_csv('x_train.csv')
y_train = pd.read_csv('y_train.csv')
x_test = pd.read_csv('x_test.csv')
y_test = pd.read_csv('y_test.csv')

y_train = y_train.to_numpy().ravel()
y_test = y_test.to_numpy().ravel()

print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)


# Helicene parameters
n_atom_types = 5          # e.g., 5 atom types (H, F, Cl, Br, I)
n_pos = 16                # number of possible positions (16)
n_features = n_atom_types * n_pos  # total one-hot features

# Load Imin_abs_mean and Imin_abs_std from the CSV file
stats = pd.read_csv('Imin_stats.csv')
Imin_abs_mean = stats['Imin_abs_mean'].values[0]
Imin_abs_std = stats['Imin_abs_std'].values[0]

# Load the pre-trained model

model_path = './CV_Models/Imin_model_CV'
best_model = tf.keras.models.load_model(model_path)

print("Model loaded successfully!")

# Load the lower and upper quantile models
model_lower =  tf.keras.models.load_model('I_model_lower.h5', compile=False)
model_upper =  tf.keras.models.load_model('I_model_upper.h5', compile=False)

print("Quantile models loaded successfully!")
# Out:
# x_train shape: (946, 80)
# y_train shape: (946,)
# x_test shape: (237, 80)
# y_test shape: (237,)
# Model loaded successfully!
# Quantile models loaded successfully!

# %% [markdown]
# # Data analysis from mono to hexa-halogenated [6]Helicenes

# %%
# Import combinatory library to generate combinations
from itertools import combinations, product, permutations

# %%
# Define the positions in the [6]Helicene molecule
positions = list(range(1, 17))  # Posiciones 1 a 16

# Define the halogens
halogens = ['F', 'Cl', 'Br', 'I']

# %%
from time import perf_counter

# ----------------------------
# Configuration
halogen_to_index = {'H': 0, 'F': 1, 'Cl': 2, 'Br': 3, 'I': 4}
BATCH_SIZE = 4096
# ----------------------------

# Fast one-hot encoder
def encode_batch(molecules):
    one_hot = np.zeros((len(molecules), n_pos * n_atom_types), dtype=np.float32)
    for i, mol in enumerate(molecules):
        for j, atom in enumerate(mol):
            idx = halogen_to_index[atom]
            one_hot[i, j * n_atom_types + idx] = 1.0
    return one_hot

# Molecule generator with symmetry filtering
def generate_unique_molecules(n_subs):
    visited = set()
    for pos_comb in combinations(positions, n_subs):
        for hal_comb in product(halogens, repeat=n_subs):
            mol = ['H'] * n_pos
            for pos, hal in zip(pos_comb, hal_comb):
                mol[pos - 1] = hal
            mol_tuple = tuple(mol)
            mol_rev = tuple(mol[::-1])
            if mol_rev in visited:
                continue
            visited.add(mol_tuple)
            yield mol

# Main predictor
def predict_imin_substituted(n_subs, model, mean, std):
    print(f"\n Predicting {n_subs}-halogenated molecules...")
    start_total = perf_counter()

    predictions = []
    batch_raw = []
    batch_id = 0

    molecule_generator = generate_unique_molecules(n_subs)

    for mol in molecule_generator:
        batch_raw.append(mol)

        if len(batch_raw) == BATCH_SIZE:
            encoded = encode_batch(batch_raw)

            with tf.device('/GPU:0'):
                pred_norm = model.predict(encoded, verbose=0)

            pred = pred_norm * std + mean
            predictions.extend([(mol, val[0]) for mol, val in zip(batch_raw, pred)])

            if batch_id % 10 == 0:
                print(f"Batch {batch_id}: processed {len(predictions)} molecules")
            batch_raw.clear()
            batch_id += 1

    # Process leftover molecules
    if batch_raw:
        encoded = encode_batch(batch_raw)
        with tf.device('/GPU:0'):
            pred_norm = model.predict(encoded, verbose=0)
        pred = pred_norm * std + mean
        predictions.extend([(mol, val[0]) for mol, val in zip(batch_raw, pred)])
        batch_raw.clear()

    # Sort by predicted Imin
    predictions.sort(key=lambda x: x[1], reverse=False)

    # Summary
    print(f"\nTop 10 {n_subs}-halogenated molecules:")
    for i, (mol, imin) in enumerate(predictions[:10]):
        print(f"{i+1:2d}. Imin = {imin:.2f} → {mol}")

    print(f"\n Finished: {len(predictions)} molecules in {perf_counter() - start_total:.2f} s")

    return predictions

# %% [markdown]
# # Data analysis for Mono-halogenated [6]Helicene

# %%
# Function to generate unique substitutions with one halogen
def generate_unique_substitutions(positions, halogens):
    unique_substitutions = []
    for halogen in halogens:
        # Generate all combinations of one halogen substitution
        for pos in positions:
            # Create a molecule with all hydrogens
            molecule = ['H'] * len(positions)
            # Substitute the halogen at the specified position
            molecule[pos-1] = halogen
            # Add the molecule to the list if its reverse is not already included
            if molecule[::-1] not in unique_substitutions:
                unique_substitutions.append(molecule)
    return unique_substitutions

# Generate the unique substitutions
unique_substitutions = generate_unique_substitutions(positions, halogens)

# Print the results
print(f"Number of unique substitutions: {len(unique_substitutions)}")
for sub in unique_substitutions:
    print(sub)

# Function to encode a molecule into a one-hot vector
def encode_molecule(molecule, n_pos, n_atom_types):
    one_hot = np.zeros((1, n_pos * n_atom_types))
    atom_types = ['H', 'F', 'Cl', 'Br', 'I']
    for i, atom in enumerate(molecule):
        atom_index = atom_types.index(atom)
        one_hot[0, i * n_atom_types + atom_index] = 1.0
    return one_hot

# Predict Imin for all molecules
mono_predictions = []
for molecule in unique_substitutions:
    encoded_molecule = encode_molecule(molecule, n_pos=16, n_atom_types=5)
    pred_normalized = best_model.predict(encoded_molecule).ravel()
    pred = pred_normalized * Imin_abs_std + Imin_abs_mean  # Denormalize
    mono_predictions.append((molecule, pred[0]))

# Mean Imin value
mean_imin = np.mean([pred[1] for pred in mono_predictions])
print(f"Mean Iminvalue for all mono-halogenated molecules: {mean_imin:.2f}")

# Sort predictions by Imin value in descending order
mono_predictions.sort(key=lambda x: x[1], reverse=False)

# Print the top 10 molecules with the highest Imin values
print("\nTop 10 Mono-halogenated Molecules with Highest Imin Values:")
for i, (molecule, imin) in enumerate(mono_predictions[:10]):
    print(f"Rank {i + 1}: Imin = {imin:.2f}")
    print(f"Molecule: {molecule}")
    print("-" * 50)
# Out:
# Number of unique substitutions: 32
# ['F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['Cl', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'Cl', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'Cl', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'Cl', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'H', 'Cl', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'H', 'H', 'Cl', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'H', 'H', 'H', 'Cl', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'H', 'H', 'H', 'H', 'Cl', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['Br', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'Br', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'Br', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'Br', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'H', 'Br', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'H', 'H', 'Br', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'H', 'H', 'H', 'Br', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'H', 'H', 'H', 'H', 'Br', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['I', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'I', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'I', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'I', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'H', 'I', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'H', 'H', 'I', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'H', 'H', 'H', 'I', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# ['H', 'H', 'H', 'H', 'H', 'H', 'H', 'I', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# 1/1 [==============================] - 1s 783ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# Mean Iminvalue for all mono-halogenated molecules: 344.20
#
# Top 10 Mono-halogenated Molecules with Highest Imin Values:
# Rank 1: Imin = 339.80
# Molecule: ['H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# --------------------------------------------------
# Rank 2: Imin = 340.10
# Molecule: ['H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# --------------------------------------------------
# Rank 3: Imin = 340.93
# Molecule: ['H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# --------------------------------------------------
# Rank 4: Imin = 341.21
# Molecule: ['H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# --------------------------------------------------
# Rank 5: Imin = 341.30
# Molecule: ['H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# --------------------------------------------------
# Rank 6: Imin = 341.34
# Molecule: ['H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# --------------------------------------------------
# Rank 7: Imin = 341.51
# Molecule: ['H', 'H', 'Cl', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# --------------------------------------------------
# Rank 8: Imin = 341.57
# Molecule: ['H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# --------------------------------------------------
# Rank 9: Imin = 341.93
# Molecule: ['H', 'H', 'Br', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# --------------------------------------------------
# Rank 10: Imin = 342.35
# Molecule: ['F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# --------------------------------------------------

# %% [markdown]
# # Location of Halogens in Monohalogenated [6]Helicenes

# %%
# Initialize a dictionary to count halogen occurrences at each position
halogen_counts = {halogen: [0] * len(positions) for halogen in halogens}

# Count occurrences of each halogen at each position
for molecule, _ in mono_predictions:  # Use predictions from the monohalogenated case
    for pos, atom in enumerate(molecule):
        if atom in halogens:
            halogen_counts[atom][pos] += 1
            
# Plot the results
plt.figure(figsize=(10, 6))

# Define the width of each bar and the offset for each halogen
bar_width = 0.2
offsets = [-1.5 * bar_width, -0.5 * bar_width, 0.5 * bar_width, 1.5 * bar_width]  # Adjust offsets for 4 halogens

# Plot each halogen's counts with a unique color and offset
for i, (halogen, counts) in enumerate(halogen_counts.items()):
    plt.bar(
        [pos + offsets[i] for pos in positions],  # Offset positions for each halogen
        counts,
        width=bar_width,
        label=halogen,
        alpha=0.7
    )

plt.xlabel("Position", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.xticks(positions)  # Ensure the x-axis ticks align with positions
plt.legend(title="Halogen")
plt.grid(False)
plt.show()

# %% [markdown]
# # ΔI_min by Position for Monohalogenated [6]Helicene

# %%
# Define the positions in the [6]Helicene molecule as an array
positions_array = np.arange(1, 17)  # Positions 1 to 16

# Step 1: Get Imin for the all-H molecule
base_subs = ['H'] * 16
encoded_H = encode_molecule(base_subs, n_pos=16, n_atom_types=5)
imin_H = float(best_model.predict(encoded_H)[0])

# Step 2: Build ΔImin by position per halogen from existing mono_predictions
delta_imin = {hal: [0.0] * 16 for hal in halogens}

for molecule, imin in mono_predictions:
    # Find the substituted position and the halogen used
    for idx, atom in enumerate(molecule):
        if atom in halogens:
            pos = idx  # 0-based index
            hal = atom
            break
    delta = imin - imin_H
    delta_imin[hal][pos] = delta

# Step 3: Plotting
bar_width = 0.2
offsets = [-1.5, -0.5, 0.5, 1.5]

fig, ax = plt.subplots(figsize=(12, 6))

for i, hal in enumerate(halogens):
    pos_shifted = positions_array + offsets[i] * bar_width
    ax.bar(pos_shifted, delta_imin[hal], width=bar_width, label=hal)

ax.set_xticks(positions_array)
ax.set_xticklabels(positions_array)
ax.set_xlabel('Position')
ax.set_ylabel('ΔI_min')
ax.legend(title='Halogen')
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 13ms/step

# %% [markdown]
# # Prediction of the TOP 10 using encode_batch
# For low number of molecules to predict is more suitable to dont use batch since it can make poor generalizations since it's predicting many molecules at one instead of going one by one.

# %%
mono_predictions = predict_imin_substituted(
    n_subs=1,
    model=best_model,
    mean=Imin_abs_mean,
    std=Imin_abs_std
)
# Out:
#  Predicting 1-halogenated molecules...
#
# Top 10 1-halogenated molecules:
#  1. Imin = 339.80 → ['H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
#  2. Imin = 340.10 → ['H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
#  3. Imin = 340.93 → ['H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
#  4. Imin = 341.21 → ['H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
#  5. Imin = 341.30 → ['H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
#  6. Imin = 341.34 → ['H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
#  7. Imin = 341.51 → ['H', 'H', 'Cl', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
#  8. Imin = 341.57 → ['H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
#  9. Imin = 341.93 → ['H', 'H', 'Br', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# 10. Imin = 342.35 → ['F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
#
#  Finished: 32 molecules in 0.04 s

# %% [markdown]
# # Data analysis for Di-halogenated [6]Helicene

# %% [markdown]
# # Prediction of the TOP 10 using encode_batch
# Now we have 976 molecules. Still a low number to use batches.

# %%
BATCH_SIZE = 32
di_predictions = predict_imin_substituted(
    n_subs=2,
    model=best_model,
    mean=Imin_abs_mean,
    std=Imin_abs_std
)
# Out:
#  Predicting 2-halogenated molecules...
# Batch 0: processed 32 molecules
# Batch 10: processed 352 molecules
# Batch 20: processed 672 molecules
#
# Top 10 2-halogenated molecules:
#  1. Imin = 339.68 → ['H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H']
#  2. Imin = 339.95 → ['H', 'F', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
#  3. Imin = 339.98 → ['H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H']
#  4. Imin = 340.23 → ['H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H']
#  5. Imin = 340.79 → ['H', 'H', 'F', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
#  6. Imin = 340.82 → ['H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H']
#  7. Imin = 341.04 → ['H', 'H', 'F', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
#  8. Imin = 341.05 → ['H', 'H', 'F', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
#  9. Imin = 341.07 → ['H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# 10. Imin = 341.12 → ['H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H']
#
#  Finished: 976 molecules in 0.95 s

# %% [markdown]
# # Individual predictions
# Predictions without batches to prevent poor generalization since we only have 976 molecules.

# %%
# Generate unique di-halogenated molecules
unique_patterns = set()
for pos_pair in combinations(positions, 2):  # Choose 2 positions from 16
    for hal_pair in product(halogens, repeat=2):  # All combinations of 2 halogens
        # Create a molecule with all hydrogens
        molecule = ['H'] * len(positions)
        # Place the halogens at the specified positions
        molecule[pos_pair[0] - 1] = hal_pair[0]  # Adjust for 0-based indexing
        molecule[pos_pair[1] - 1] = hal_pair[1]
        # Add the molecule to the set if its reverse is not already included
        if tuple(molecule[::-1]) not in unique_patterns:  # Convert reversed list to tuple
            unique_patterns.add(tuple(molecule))  # Convert molecule to tuple for immutability

# Output
print(f"Total unique di-halogenated molecules: {len(unique_patterns)}")
print("Examples:")
for i, molecule in enumerate(sorted(unique_patterns)[:5]):  # Show first 5 examples
    print(f"{i + 1}: {list(molecule)}")  # Convert tuple back to list for display
    
# Predict Imin for all molecules
di_predictions = []
for molecule in unique_patterns:
    encoded_molecule = encode_molecule(list(molecule), n_pos=16, n_atom_types=5)  # Convert tuple back to list
    pred_normalized = best_model.predict(encoded_molecule).ravel()
    pred = pred_normalized * Imin_abs_std + Imin_abs_mean  # Denormalize
    di_predictions.append((list(molecule), pred[0]))

# Sort predictions by Imin value in descending order
di_predictions.sort(key=lambda x: x[1], reverse=False)

# Mean Imin value of top 100 highest Imin values
mean_imin_100 = np.mean([pred[1] for pred in di_predictions[:100]])
print(f"Mean Imin value for top 100 di-halogenated molecules: {mean_imin_100:.2f}")

# Print the top 10 molecules with the highest Imin values
print("\nTop 10 Di-halogenated Molecules with Highest Imin Values:")
for i, (molecule, imin) in enumerate(di_predictions[:10]):
    print(f"Rank {i + 1}: Imin = {imin:.2f}")
    print(f"Molecule: {molecule}")
    print("-" * 50)
# Out:
# Total unique di-halogenated molecules: 976
# Examples:
# 1: ['Br', 'Br', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# 2: ['Br', 'Cl', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# 3: ['Br', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# 4: ['Br', 'H', 'Br', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# 5: ['Br', 'H', 'Cl', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# Mean Imin value for top 100 di-halogenated molecules: 342.30
#
# Top 10 Di-halogenated Molecules with Highest Imin Values:
# Rank 1: Imin = 339.68
# Molecule: ['H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H']
# --------------------------------------------------
# Rank 2: Imin = 339.95
# Molecule: ['H', 'F', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# --------------------------------------------------
# Rank 3: Imin = 339.98
# Molecule: ['H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H']
# --------------------------------------------------
# Rank 4: Imin = 340.23
# Molecule: ['H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H']
# --------------------------------------------------
# Rank 5: Imin = 340.79
# Molecule: ['H', 'H', 'F', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# --------------------------------------------------
# Rank 6: Imin = 340.82
# Molecule: ['H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H']
# --------------------------------------------------
# Rank 7: Imin = 341.04
# Molecule: ['H', 'H', 'F', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# --------------------------------------------------
# Rank 8: Imin = 341.05
# Molecule: ['H', 'H', 'F', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# --------------------------------------------------
# Rank 9: Imin = 341.07
# Molecule: ['H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# --------------------------------------------------
# Rank 10: Imin = 341.12
# Molecule: ['H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H']
# --------------------------------------------------

# %% [markdown]
# # Predictions with Imin higher than 700
# This conditional is made to then visualize in a plot the positions tendecy of dihalogenated molecules. Batch is used just to make it quick since we have done to predictions before of the same thing for the sake of the analysis for a better and quicker predicting function.

# %%
# Track mirrored molecules
visited_patterns = set()

# Good candidates
good_candidates = []

# Batch buffer
batch_molecules = []
batch_raw_molecules = []

BATCH_SIZE = 32

for pos_duplet in combinations(positions, 2):
    for hal_duplet in product(halogens, repeat=2):
        molecule = ['H'] * len(positions)
        for pos, hal in zip(pos_duplet, hal_duplet):
            molecule[pos - 1] = hal
        
        mol_tuple = tuple(molecule)
        mol_rev = tuple(molecule[::-1])

        visited_patterns.add(mol_tuple)

        encoded = encode_molecule(molecule, n_pos=16, n_atom_types=5)
        batch_molecules.append(encoded) 
        batch_raw_molecules.append(list(molecule)) 

        if len(batch_molecules) == BATCH_SIZE:
            batch_array = np.vstack(batch_molecules)
            batch_pred_normalized = best_model.predict(batch_array)
            batch_pred = batch_pred_normalized * Imin_abs_std + Imin_abs_mean

            for mol, pred in zip(batch_raw_molecules, batch_pred):
                if pred[0] <= -400:
                    good_candidates.append((mol, pred[0]))

            batch_molecules.clear()
            batch_raw_molecules.clear()

# Process leftovers
if batch_molecules:
    batch_array = np.vstack(batch_molecules)
    batch_pred_normalized = best_model.predict(batch_array)
    batch_pred = batch_pred_normalized * Imin_abs_std + Imin_abs_mean

    for mol, pred in zip(batch_raw_molecules, batch_pred):
        if pred[0] <= -400:
            good_candidates.append(list(mol,pred[0]))

# Sort results
good_candidates.sort(key=lambda x: x[1], reverse=False)

print(f"\nTotal molecules with Imin <= -200: {len(good_candidates)}")
# Out:
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
#
# Total molecules with Imin <= -200: 0

# %% [markdown]
# # Location of Halogens in Dihalogenated [6]Helicenes

# %%
# Count the occurrences of each halogen at each position
halogen_counts = {halogen: [0] * len(positions) for halogen in halogens}
for molecule, _ in good_candidates:  # Unpack the tuple
    for pos, atom in enumerate(molecule):
        if atom in halogens:
            halogen_counts[atom][pos] += 1

# Plot the results
plt.figure(figsize=(10, 6))
bar_width = 0.2
offsets = [-1.5 * bar_width, -0.5 * bar_width, 0.5 * bar_width, 1.5 * bar_width]  # For 4 halogens

for i, (halogen, counts) in enumerate(halogen_counts.items()):
    plt.bar(
        [pos + offsets[i] for pos in range(len(positions))],
        counts,
        width=bar_width,
        label=halogen,
        alpha=0.7
    )

plt.xlabel("Position", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.xticks(range(len(positions)), [str(p) for p in positions])
plt.legend(title="Halogen")
plt.grid(False)
plt.show()

# %% [markdown]
# # ΔI_min by Position for Dihalogenated [6]Helicene

# %%
# Reuse predictions
mono_imin = {tuple(molecule): imin for molecule, imin in mono_predictions}
di_imin = {tuple(molecule): imin for molecule, imin in di_predictions}

# Initialize accumulators
delta_imin_dihalogenated = {hal: [0.0] * 16 for hal in halogens}
count_deltas = {hal: [0] * 16 for hal in halogens}

# Step 1: Accumulate ΔI_min from dihalogenated molecules
for molecule, imin_di in di_imin.items():
    halogens_in_molecule = [(pos, atom) for pos, atom in enumerate(molecule) if atom in halogens]
    if len(halogens_in_molecule) != 2:
        continue

    (pos_i, hal_i), (pos_j, hal_j) = halogens_in_molecule

    mono_i = list(molecule)
    mono_i[pos_j] = 'H'
    mono_j = list(molecule)
    mono_j[pos_i] = 'H'

    imin_mono_i = mono_imin.get(tuple(mono_i), 0)
    imin_mono_j = mono_imin.get(tuple(mono_j), 0)

    delta_i = imin_di - imin_mono_i
    delta_j = imin_di - imin_mono_j

    delta_imin_dihalogenated[hal_i][pos_i] += delta_i
    delta_imin_dihalogenated[hal_j][pos_j] += delta_j
    count_deltas[hal_i][pos_i] += 1
    count_deltas[hal_j][pos_j] += 1

# Step 2: Compute symmetric-averaged ΔI_min
for hal in halogens:
    for i in range(8):  # 0 to 7
        j = 15 - i  # Mirror position
        # Combine values and counts
        total_delta = delta_imin_dihalogenated[hal][i] + delta_imin_dihalogenated[hal][j]
        total_count = count_deltas[hal][i] + count_deltas[hal][j]
        # Avoid division by zero
        avg = total_delta / total_count if total_count > 0 else 0.0
        # Assign symmetric average to both positions
        delta_imin_dihalogenated[hal][i] = avg
        delta_imin_dihalogenated[hal][j] = avg

# Step 3: Plotting
positions_array = np.arange(16)
bar_width = 0.2
offsets = [-1.5, -0.5, 0.5, 1.5]

fig, ax = plt.subplots(figsize=(12, 6))

for i, hal in enumerate(halogens):
    pos_shifted = positions_array + offsets[i] * bar_width
    ax.bar(pos_shifted, delta_imin_dihalogenated[hal], width=bar_width, label=hal)

ax.set_xticks(positions_array)
ax.set_xticklabels(positions_array + 1)
ax.set_xlabel('Position')
ax.set_ylabel('Average ΔI_min')
ax.legend(title='Halogen')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data analysis for Tri-halogenated [6]Helicene

# %% [markdown]
# # Predictions with Imin higher than 700

# %%
# Track mirrored molecules
visited_patterns = set()

# Good candidates
good_candidates = []

# Batch buffer
batch_molecules = []
batch_raw_molecules = []

BATCH_SIZE = 512

for pos_triplet in combinations(positions, 3):
    for hal_triplet in product(halogens, repeat=3):
        molecule = ['H'] * len(positions)
        for pos, hal in zip(pos_triplet, hal_triplet):
            molecule[pos - 1] = hal
        
        mol_tuple = tuple(molecule)
        mol_rev = tuple(molecule[::-1])

        visited_patterns.add(mol_tuple)

        encoded = encode_molecule(molecule, n_pos=16, n_atom_types=5)
        batch_molecules.append(encoded) 
        batch_raw_molecules.append(list(molecule)) 

        if len(batch_molecules) == BATCH_SIZE:
            batch_array = np.vstack(batch_molecules)
            batch_pred_normalized = best_model.predict(batch_array)
            batch_pred = batch_pred_normalized * Imin_abs_std + Imin_abs_mean

            for mol, pred in zip(batch_raw_molecules, batch_pred):
                if pred[0] <= -600:
                    good_candidates.append((mol, pred[0]))

            batch_molecules.clear()
            batch_raw_molecules.clear()

# Process leftovers
if batch_molecules:
    batch_array = np.vstack(batch_molecules)
    batch_pred_normalized = best_model.predict(batch_array)
    batch_pred = batch_pred_normalized * Imin_abs_std + Imin_abs_mean

    for mol, pred in zip(batch_raw_molecules, batch_pred):
        if pred[0] <= -600:
            good_candidates.append(list(mol,pred[0]))

# Sort results
good_candidates.sort(key=lambda x: x[1], reverse=False)

# Print top 10
print("\nTop 10 Tri-halogenated Molecules with Highest Imin Values (Imin >= 700):")
for i, (molecule, imin) in enumerate(good_candidates[:10]):
    print(f"Rank {i + 1}: Imin = {imin:.2f}")
    print(f"Molecule: {molecule}")
    print("-" * 50)

print(f"\nTotal molecules with Imin <= -400: {len(good_candidates)}")
# Out:
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
#
# Top 10 Tri-halogenated Molecules with Highest Imin Values (Imin >= 700):
#
# Total molecules with Imin <= -400: 0

# %% [markdown]
# # Location of Halogens in Trihalogenated [6]Helicenes

# %%
# Count the occurrences of each halogen at each position
halogen_counts = {halogen: [0] * len(positions) for halogen in halogens}
for molecule, _ in good_candidates:  # Unpack the tuple
    for pos, atom in enumerate(molecule):
        if atom in halogens:
            halogen_counts[atom][pos] += 1

# Plot the results
plt.figure(figsize=(10, 6))
bar_width = 0.2
offsets = [-1.5 * bar_width, -0.5 * bar_width, 0.5 * bar_width, 1.5 * bar_width]  # For 4 halogens

for i, (halogen, counts) in enumerate(halogen_counts.items()):
    plt.bar(
        [pos + offsets[i] for pos in range(len(positions))],
        counts,
        width=bar_width,
        label=halogen,
        alpha=0.7
    )

plt.xlabel("Position", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.xticks(range(len(positions)), [str(p) for p in positions])
plt.legend(title="Halogen")
plt.grid(False)
plt.show()

# %% [markdown]
# # Prediction of the TOP 10 using encode_batch
# Now we have 17920 molecules. So we can use a batch to make it a bit faster without loosing generalization.

# %%
BATCH_SIZE = 128
tri_predictions = predict_imin_substituted(
    n_subs=3,
    model=best_model,
    mean=Imin_abs_mean,
    std=Imin_abs_std
)
# Out:
#  Predicting 3-halogenated molecules...
# Batch 0: processed 128 molecules
# Batch 10: processed 1408 molecules
# Batch 20: processed 2688 molecules
# Batch 30: processed 3968 molecules
# Batch 40: processed 5248 molecules
# Batch 50: processed 6528 molecules
# Batch 60: processed 7808 molecules
# Batch 70: processed 9088 molecules
# Batch 80: processed 10368 molecules
# Batch 90: processed 11648 molecules
# Batch 100: processed 12928 molecules
# Batch 110: processed 14208 molecules
# Batch 120: processed 15488 molecules
# Batch 130: processed 16768 molecules
#
# Top 10 3-halogenated molecules:
#  1. Imin = 339.83 → ['H', 'F', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H']
#  2. Imin = 340.10 → ['H', 'F', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H']
#  3. Imin = 340.67 → ['H', 'H', 'F', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H']
#  4. Imin = 340.94 → ['H', 'H', 'F', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H']
#  5. Imin = 340.97 → ['H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'F', 'H', 'H']
#  6. Imin = 340.99 → ['H', 'F', 'F', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
#  7. Imin = 340.99 → ['H', 'F', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H']
#  8. Imin = 340.99 → ['H', 'H', 'F', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H']
#  9. Imin = 341.05 → ['H', 'F', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H']
# 10. Imin = 341.20 → ['H', 'H', 'F', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H']
#
#  Finished: 17920 molecules in 5.54 s

# %% [markdown]
# # ΔI_min by Position for Trihalogenated [6]Helicene (vs Dihalogenated)

# %%
# Step 0: Prepare dictionaries from previous predictions
di_imin = {tuple(molecule): imin for molecule, imin in di_predictions}
tri_imin = {tuple(molecule): imin for molecule, imin in tri_predictions}

# Initialize accumulators
delta_imin_trihalogenated = {hal: [0.0] * 16 for hal in halogens}
count_deltas = {hal: [0] * 16 for hal in halogens}

# Step 1: Accumulate ΔI_min from trihalogenated vs dihalogenated
for molecule, imin_tri in tri_imin.items():
    # Find halogen positions
    halogens_in_molecule = [(pos, atom) for pos, atom in enumerate(molecule) if atom in halogens]
    if len(halogens_in_molecule) != 3:
        continue  # Skip invalid entries

    # For each of the three dihalogenated variants (remove one halogen)
    for idx in range(3):
        (pos_removed, hal_removed) = halogens_in_molecule[idx]
        di_molecule = list(molecule)
        di_molecule[pos_removed] = 'H'

        imin_di = di_imin.get(tuple(di_molecule), None)
        if imin_di is None:
            continue  # Skip if corresponding dihalogenated molecule is missing

        delta = imin_tri - imin_di
        delta_imin_trihalogenated[hal_removed][pos_removed] += delta
        count_deltas[hal_removed][pos_removed] += 1

# Step 2: Enforce symmetry (mirror-averaged values)
for hal in halogens:
    for i in range(8):
        j = 15 - i  # Mirror position
        total_delta = delta_imin_trihalogenated[hal][i] + delta_imin_trihalogenated[hal][j]
        total_count = count_deltas[hal][i] + count_deltas[hal][j]
        avg = total_delta / total_count if total_count > 0 else 0.0
        delta_imin_trihalogenated[hal][i] = avg
        delta_imin_trihalogenated[hal][j] = avg

# Step 3: Plotting
positions_array = np.arange(16)
bar_width = 0.2
offsets = [-1.5, -0.5, 0.5, 1.5]

fig, ax = plt.subplots(figsize=(14, 6))

for i, hal in enumerate(halogens):
    pos_shifted = positions_array + offsets[i] * bar_width
    ax.bar(pos_shifted, delta_imin_trihalogenated[hal], width=bar_width, label=hal)

ax.set_xticks(positions_array)
ax.set_xticklabels(positions_array + 1)
ax.set_xlabel('Position')
ax.set_ylabel('Average ΔI_min')
ax.legend(title='Halogen')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data analysis for tetra-halogenated [6]Helicenes

# %% [markdown]
# # Predictions with Imin higher than 700

# %%
# Track mirrored molecules
visited_patterns = set()

# Good candidates
good_candidates = []

# Batch buffer
batch_molecules = []
batch_raw_molecules = []

BATCH_SIZE = 512

for pos_quad in combinations(positions, 4):
    for hal_quad in product(halogens, repeat=4):
        molecule = ['H'] * len(positions)
        for pos, hal in zip(pos_quad, hal_quad):
            molecule[pos - 1] = hal
        
        mol_tuple = tuple(molecule)
        mol_rev = tuple(molecule[::-1])

        visited_patterns.add(mol_tuple)

        encoded = encode_molecule(molecule, n_pos=16, n_atom_types=5)
        batch_molecules.append(encoded) 
        batch_raw_molecules.append(list(molecule)) 

        if len(batch_molecules) == BATCH_SIZE:
            batch_array = np.vstack(batch_molecules)
            batch_pred_normalized = best_model.predict(batch_array)
            batch_pred = batch_pred_normalized * Imin_abs_std + Imin_abs_mean

            for mol, pred in zip(batch_raw_molecules, batch_pred):
                if pred[0] <= -600:
                    good_candidates.append((mol, pred[0]))

            batch_molecules.clear()
            batch_raw_molecules.clear()

# Process leftovers
if batch_molecules:
    batch_array = np.vstack(batch_molecules)
    batch_pred_normalized = best_model.predict(batch_array)
    batch_pred = batch_pred_normalized * Imin_abs_std + Imin_abs_mean

    for mol, pred in zip(batch_raw_molecules, batch_pred):
        if pred[0] <= -600:
            good_candidates.append(list(mol,pred[0]))

# Sort results
good_candidates.sort(key=lambda x: x[1], reverse=False)

# Print top 10
print("\nTop 10 Tetra-halogenated Molecules with Highest Imin Values (Imin <= -600):")
for i, (molecule, imin) in enumerate(good_candidates[:10]):
    print(f"Rank {i + 1}: Imin = {imin:.2f}")
    print(f"Molecule: {molecule}")
    print("-" * 50)

print(f"\nTotal molecules with Imin <= -600: {len(good_candidates)}")
# Out:
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
#
# Top 10 Tetra-halogenated Molecules with Highest Imin Values (Imin <= -600):
#
# Total molecules with Imin <= -600: 0

# %% [markdown]
# # Location of Halogens in Tetrahalogenated [6]Helicenes

# %%
# Count the occurrences of each halogen at each position
halogen_counts = {halogen: [0] * len(positions) for halogen in halogens}
for molecule, _ in good_candidates:  # Unpack the tuple
    for pos, atom in enumerate(molecule):
        if atom in halogens:
            halogen_counts[atom][pos] += 1

# Plot the results
plt.figure(figsize=(10, 6))
bar_width = 0.2
offsets = [-1.5 * bar_width, -0.5 * bar_width, 0.5 * bar_width, 1.5 * bar_width]  # For 4 halogens

for i, (halogen, counts) in enumerate(halogen_counts.items()):
    plt.bar(
        [pos + offsets[i] for pos in range(len(positions))],
        counts,
        width=bar_width,
        label=halogen,
        alpha=0.7
    )

plt.xlabel("Position", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.xticks(range(len(positions)), [str(p) for p in positions])
plt.legend(title="Halogen")
plt.grid(False)
plt.show()

# %% [markdown]
# # Prediction of the TOP 10 using encode_batch
# Now we have 233184 molecules. So we can use a batch to make it faster without loosing generalization.

# %%
BATCH_SIZE = 512
tetra_predictions = predict_imin_substituted(
    n_subs=4,
    model=best_model,
    mean=Imin_abs_mean,
    std=Imin_abs_std
)
# Out:
#  Predicting 4-halogenated molecules...
# Batch 0: processed 512 molecules
# Batch 10: processed 5632 molecules
# Batch 20: processed 10752 molecules
# Batch 30: processed 15872 molecules
# Batch 40: processed 20992 molecules
# Batch 50: processed 26112 molecules
# Batch 60: processed 31232 molecules
# Batch 70: processed 36352 molecules
# Batch 80: processed 41472 molecules
# Batch 90: processed 46592 molecules
# Batch 100: processed 51712 molecules
# Batch 110: processed 56832 molecules
# Batch 120: processed 61952 molecules
# Batch 130: processed 67072 molecules
# Batch 140: processed 72192 molecules
# Batch 150: processed 77312 molecules
# Batch 160: processed 82432 molecules
# Batch 170: processed 87552 molecules
# Batch 180: processed 92672 molecules
# Batch 190: processed 97792 molecules
# Batch 200: processed 102912 molecules
# Batch 210: processed 108032 molecules
# Batch 220: processed 113152 molecules
# Batch 230: processed 118272 molecules
# Batch 240: processed 123392 molecules
# Batch 250: processed 128512 molecules
# Batch 260: processed 133632 molecules
# Batch 270: processed 138752 molecules
# Batch 280: processed 143872 molecules
# Batch 290: processed 148992 molecules
# Batch 300: processed 154112 molecules
# Batch 310: processed 159232 molecules
# Batch 320: processed 164352 molecules
# Batch 330: processed 169472 molecules
# Batch 340: processed 174592 molecules
# Batch 350: processed 179712 molecules
# Batch 360: processed 184832 molecules
# Batch 370: processed 189952 molecules
# Batch 380: processed 195072 molecules
# Batch 390: processed 200192 molecules
# Batch 400: processed 205312 molecules
# Batch 410: processed 210432 molecules
# Batch 420: processed 215552 molecules
# Batch 430: processed 220672 molecules
# Batch 440: processed 225792 molecules
# Batch 450: processed 230912 molecules
#
# Top 10 4-halogenated molecules:
#  1. Imin = 339.95 → ['H', 'F', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'F', 'H']
#  2. Imin = 340.85 → ['H', 'F', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'F', 'H', 'H']
#  3. Imin = 340.89 → ['H', 'F', 'F', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H']
#  4. Imin = 341.12 → ['H', 'F', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'F', 'H', 'H']
#  5. Imin = 341.15 → ['H', 'F', 'F', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H']
#  6. Imin = 341.16 → ['H', 'F', 'F', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H']
#  7. Imin = 341.17 → ['H', 'F', 'F', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'F', 'H', 'H']
#  8. Imin = 341.20 → ['H', 'F', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'F', 'H']
#  9. Imin = 341.20 → ['H', 'F', 'F', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H']
# 10. Imin = 341.28 → ['H', 'F', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'F', 'H', 'H']
#
#  Finished: 233184 molecules in 30.11 s

# %% [markdown]
# # ΔI_min by Position for Tetrahalogenated [6]Helicene (vs Trihalogenated)

# %%
# Step 0: Prepare prediction dictionaries
tri_imin = {tuple(molecule): imin for molecule, imin in tri_predictions}
tetra_imin = {tuple(molecule): imin for molecule, imin in tetra_predictions}

# Initialize accumulators
delta_imin_tetrahalogenated = {hal: [0.0] * 16 for hal in halogens}
count_deltas = {hal: [0] * 16 for hal in halogens}

# Step 1: Accumulate ΔImin by comparing tetra- vs tri-halogenated molecules
for molecule, imin_tetra in tetra_imin.items():
    halogens_in_molecule = [(pos, atom) for pos, atom in enumerate(molecule) if atom in halogens]
    if len(halogens_in_molecule) != 4:
        continue

    # Generate each tri-halogenated version (remove one halogen at a time)
    for idx in range(4):
        pos_removed, hal_removed = halogens_in_molecule[idx]
        tri_molecule = list(molecule)
        tri_molecule[pos_removed] = 'H'

        imin_tri = tri_imin.get(tuple(tri_molecule), None)
        if imin_tri is None:
            continue

        delta = imin_tetra - imin_tri
        delta_imin_tetrahalogenated[hal_removed][pos_removed] += delta
        count_deltas[hal_removed][pos_removed] += 1

# Step 2: Enforce symmetry by mirror-averaging
for hal in halogens:
    for i in range(8):
        j = 15 - i  # Mirror position
        total_delta = delta_imin_tetrahalogenated[hal][i] + delta_imin_tetrahalogenated[hal][j]
        total_count = count_deltas[hal][i] + count_deltas[hal][j]
        avg = total_delta / total_count if total_count > 0 else 0.0
        delta_imin_tetrahalogenated[hal][i] = avg
        delta_imin_tetrahalogenated[hal][j] = avg

# Step 3: Plotting
positions_array = np.arange(16)
bar_width = 0.2
offsets = [-1.5, -0.5, 0.5, 1.5]

fig, ax = plt.subplots(figsize=(14, 6))

for i, hal in enumerate(halogens):
    pos_shifted = positions_array + offsets[i] * bar_width
    ax.bar(pos_shifted, delta_imin_tetrahalogenated[hal], width=bar_width, label=hal)

ax.set_xticks(positions_array)
ax.set_xticklabels(positions_array + 1)
ax.set_xlabel('Position')
ax.set_ylabel('Average ΔI_min')
ax.legend(title='Halogen')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data analysis for penta-halogenated [6]Helicenes

# %% [markdown]
# # Prediction of the TOP 10 using encode_batch
# Now we have 2236416 molecules. So we can use a batch to make it faster without loosing generalization.

# %%
BATCH_SIZE = 1024
penta_predictions = predict_imin_substituted(
    n_subs=5,
    model=best_model,
    mean=Imin_abs_mean,
    std=Imin_abs_std
)
# Out:
#  Predicting 5-halogenated molecules...
# Batch 0: processed 1024 molecules
# Batch 10: processed 11264 molecules
# Batch 20: processed 21504 molecules
# Batch 30: processed 31744 molecules
# Batch 40: processed 41984 molecules
# Batch 50: processed 52224 molecules
# Batch 60: processed 62464 molecules
# Batch 70: processed 72704 molecules
# Batch 80: processed 82944 molecules
# Batch 90: processed 93184 molecules
# Batch 100: processed 103424 molecules
# Batch 110: processed 113664 molecules
# Batch 120: processed 123904 molecules
# Batch 130: processed 134144 molecules
# Batch 140: processed 144384 molecules
# Batch 150: processed 154624 molecules
# Batch 160: processed 164864 molecules
# Batch 170: processed 175104 molecules
# Batch 180: processed 185344 molecules
# Batch 190: processed 195584 molecules
# Batch 200: processed 205824 molecules
# Batch 210: processed 216064 molecules
# Batch 220: processed 226304 molecules
# Batch 230: processed 236544 molecules
# Batch 240: processed 246784 molecules
# Batch 250: processed 257024 molecules
# Batch 260: processed 267264 molecules
# Batch 270: processed 277504 molecules
# Batch 280: processed 287744 molecules
# Batch 290: processed 297984 molecules
# Batch 300: processed 308224 molecules
# Batch 310: processed 318464 molecules
# Batch 320: processed 328704 molecules
# Batch 330: processed 338944 molecules
# Batch 340: processed 349184 molecules
# Batch 350: processed 359424 molecules
# Batch 360: processed 369664 molecules
# Batch 370: processed 379904 molecules
# Batch 380: processed 390144 molecules
# Batch 390: processed 400384 molecules
# Batch 400: processed 410624 molecules
# Batch 410: processed 420864 molecules
# Batch 420: processed 431104 molecules
# Batch 430: processed 441344 molecules
# Batch 440: processed 451584 molecules
# Batch 450: processed 461824 molecules
# Batch 460: processed 472064 molecules
# Batch 470: processed 482304 molecules
# Batch 480: processed 492544 molecules
# Batch 490: processed 502784 molecules
# Batch 500: processed 513024 molecules
# Batch 510: processed 523264 molecules
# Batch 520: processed 533504 molecules
# Batch 530: processed 543744 molecules
# Batch 540: processed 553984 molecules
# Batch 550: processed 564224 molecules
# Batch 560: processed 574464 molecules
# Batch 570: processed 584704 molecules
# Batch 580: processed 594944 molecules
# Batch 590: processed 605184 molecules
# Batch 600: processed 615424 molecules
# Batch 610: processed 625664 molecules
# Batch 620: processed 635904 molecules
# Batch 630: processed 646144 molecules
# Batch 640: processed 656384 molecules
# Batch 650: processed 666624 molecules
# Batch 660: processed 676864 molecules
# Batch 670: processed 687104 molecules
# Batch 680: processed 697344 molecules
# Batch 690: processed 707584 molecules
# Batch 700: processed 717824 molecules
# Batch 710: processed 728064 molecules
# Batch 720: processed 738304 molecules
# Batch 730: processed 748544 molecules
# Batch 740: processed 758784 molecules
# Batch 750: processed 769024 molecules
# Batch 760: processed 779264 molecules
# Batch 770: processed 789504 molecules
# Batch 780: processed 799744 molecules
# Batch 790: processed 809984 molecules
# Batch 800: processed 820224 molecules
# Batch 810: processed 830464 molecules
# Batch 820: processed 840704 molecules
# Batch 830: processed 850944 molecules
# Batch 840: processed 861184 molecules
# Batch 850: processed 871424 molecules
# Batch 860: processed 881664 molecules
# Batch 870: processed 891904 molecules
# Batch 880: processed 902144 molecules
# Batch 890: processed 912384 molecules
# Batch 900: processed 922624 molecules
# Batch 910: processed 932864 molecules
# Batch 920: processed 943104 molecules
# Batch 930: processed 953344 molecules
# Batch 940: processed 963584 molecules
# Batch 950: processed 973824 molecules
# Batch 960: processed 984064 molecules
# Batch 970: processed 994304 molecules
# Batch 980: processed 1004544 molecules
# Batch 990: processed 1014784 molecules
# Batch 1000: processed 1025024 molecules
# Batch 1010: processed 1035264 molecules
# Batch 1020: processed 1045504 molecules
# Batch 1030: processed 1055744 molecules
# Batch 1040: processed 1065984 molecules
# Batch 1050: processed 1076224 molecules
# Batch 1060: processed 1086464 molecules
# Batch 1070: processed 1096704 molecules
# Batch 1080: processed 1106944 molecules
# Batch 1090: processed 1117184 molecules
# Batch 1100: processed 1127424 molecules
# Batch 1110: processed 1137664 molecules
# Batch 1120: processed 1147904 molecules
# Batch 1130: processed 1158144 molecules
# Batch 1140: processed 1168384 molecules
# Batch 1150: processed 1178624 molecules
# Batch 1160: processed 1188864 molecules
# Batch 1170: processed 1199104 molecules
# Batch 1180: processed 1209344 molecules
# Batch 1190: processed 1219584 molecules
# Batch 1200: processed 1229824 molecules
# Batch 1210: processed 1240064 molecules
# Batch 1220: processed 1250304 molecules
# Batch 1230: processed 1260544 molecules
# Batch 1240: processed 1270784 molecules
# Batch 1250: processed 1281024 molecules
# Batch 1260: processed 1291264 molecules
# Batch 1270: processed 1301504 molecules
# Batch 1280: processed 1311744 molecules
# Batch 1290: processed 1321984 molecules
# Batch 1300: processed 1332224 molecules
# Batch 1310: processed 1342464 molecules
# Batch 1320: processed 1352704 molecules
# Batch 1330: processed 1362944 molecules
# Batch 1340: processed 1373184 molecules
# Batch 1350: processed 1383424 molecules
# Batch 1360: processed 1393664 molecules
# Batch 1370: processed 1403904 molecules
# Batch 1380: processed 1414144 molecules
# Batch 1390: processed 1424384 molecules
# Batch 1400: processed 1434624 molecules
# Batch 1410: processed 1444864 molecules
# Batch 1420: processed 1455104 molecules
# Batch 1430: processed 1465344 molecules
# Batch 1440: processed 1475584 molecules
# Batch 1450: processed 1485824 molecules
# Batch 1460: processed 1496064 molecules
# Batch 1470: processed 1506304 molecules
# Batch 1480: processed 1516544 molecules
# Batch 1490: processed 1526784 molecules
# Batch 1500: processed 1537024 molecules
# Batch 1510: processed 1547264 molecules
# Batch 1520: processed 1557504 molecules
# Batch 1530: processed 1567744 molecules
# Batch 1540: processed 1577984 molecules
# Batch 1550: processed 1588224 molecules
# Batch 1560: processed 1598464 molecules
# Batch 1570: processed 1608704 molecules
# Batch 1580: processed 1618944 molecules
# Batch 1590: processed 1629184 molecules
# Batch 1600: processed 1639424 molecules
# Batch 1610: processed 1649664 molecules
# Batch 1620: processed 1659904 molecules
# Batch 1630: processed 1670144 molecules
# Batch 1640: processed 1680384 molecules
# Batch 1650: processed 1690624 molecules
# Batch 1660: processed 1700864 molecules
# Batch 1670: processed 1711104 molecules
# Batch 1680: processed 1721344 molecules
# Batch 1690: processed 1731584 molecules
# Batch 1700: processed 1741824 molecules
# Batch 1710: processed 1752064 molecules
# Batch 1720: processed 1762304 molecules
# Batch 1730: processed 1772544 molecules
# Batch 1740: processed 1782784 molecules
# Batch 1750: processed 1793024 molecules
# Batch 1760: processed 1803264 molecules
# Batch 1770: processed 1813504 molecules
# Batch 1780: processed 1823744 molecules
# Batch 1790: processed 1833984 molecules
# Batch 1800: processed 1844224 molecules
# Batch 1810: processed 1854464 molecules
# Batch 1820: processed 1864704 molecules
# Batch 1830: processed 1874944 molecules
# Batch 1840: processed 1885184 molecules
# Batch 1850: processed 1895424 molecules
# Batch 1860: processed 1905664 molecules
# Batch 1870: processed 1915904 molecules
# Batch 1880: processed 1926144 molecules
# Batch 1890: processed 1936384 molecules
# Batch 1900: processed 1946624 molecules
# Batch 1910: processed 1956864 molecules
# Batch 1920: processed 1967104 molecules
# Batch 1930: processed 1977344 molecules
# Batch 1940: processed 1987584 molecules
# Batch 1950: processed 1997824 molecules
# Batch 1960: processed 2008064 molecules
# Batch 1970: processed 2018304 molecules
# Batch 1980: processed 2028544 molecules
# Batch 1990: processed 2038784 molecules
# Batch 2000: processed 2049024 molecules
# Batch 2010: processed 2059264 molecules
# Batch 2020: processed 2069504 molecules
# Batch 2030: processed 2079744 molecules
# Batch 2040: processed 2089984 molecules
# Batch 2050: processed 2100224 molecules
# Batch 2060: processed 2110464 molecules
# Batch 2070: processed 2120704 molecules
# Batch 2080: processed 2130944 molecules
# Batch 2090: processed 2141184 molecules
# Batch 2100: processed 2151424 molecules
# Batch 2110: processed 2161664 molecules
# Batch 2120: processed 2171904 molecules
# Batch 2130: processed 2182144 molecules
# Batch 2140: processed 2192384 molecules
# Batch 2150: processed 2202624 molecules
# Batch 2160: processed 2212864 molecules
# Batch 2170: processed 2223104 molecules
# Batch 2180: processed 2233344 molecules
#
# Top 10 5-halogenated molecules:
#  1. Imin = 341.03 → ['H', 'F', 'F', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'F', 'H']
#  2. Imin = 341.34 → ['H', 'F', 'F', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'F', 'H']
#  3. Imin = 341.39 → ['H', 'F', 'F', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'F', 'F', 'H']
#  4. Imin = 341.50 → ['H', 'F', 'F', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'F', 'H']
#  5. Imin = 341.65 → ['H', 'F', 'F', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'F', 'H']
#  6. Imin = 341.78 → ['H', 'F', 'F', 'H', 'H', 'H', 'F', 'H', 'H', 'F', 'H', 'H', 'H', 'F', 'H', 'H']
#  7. Imin = 341.89 → ['H', 'F', 'F', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'F', 'F', 'H', 'H']
#  8. Imin = 341.93 → ['H', 'F', 'F', 'H', 'H', 'H', 'H', 'H', 'F', 'F', 'H', 'H', 'H', 'F', 'H', 'H']
#  9. Imin = 341.97 → ['H', 'F', 'F', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'F', 'H', 'F', 'H', 'H']
# 10. Imin = 341.98 → ['H', 'F', 'F', 'H', 'H', 'H', 'F', 'F', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H']
#
#  Finished: 2236416 molecules in 205.27 s

# %% [markdown]
# # Data analysis for hexa-halogenated [6]Helicenes

# %% [markdown]
# # Prediction of the TOP 10 using encode_batch
# Now we have 16402176 molecules. So we can use a batch to make it faster without loosing generalization.

# %%
BATCH_SIZE=4096

hexa_predictions = predict_imin_substituted(
    n_subs=6,
    model=best_model,
    mean=Imin_abs_mean,
    std=Imin_abs_std
)
# Out:
#  Predicting 6-halogenated molecules...
# Batch 0: processed 4096 molecules
# Batch 10: processed 45056 molecules
# Batch 20: processed 86016 molecules
# Batch 30: processed 126976 molecules
# Batch 40: processed 167936 molecules
# Batch 50: processed 208896 molecules
# Batch 60: processed 249856 molecules
# Batch 70: processed 290816 molecules
# Batch 80: processed 331776 molecules
# Batch 90: processed 372736 molecules
# Batch 100: processed 413696 molecules
# Batch 110: processed 454656 molecules
# Batch 120: processed 495616 molecules
# Batch 130: processed 536576 molecules
# Batch 140: processed 577536 molecules
# Batch 150: processed 618496 molecules
# Batch 160: processed 659456 molecules
# Batch 170: processed 700416 molecules
# Batch 180: processed 741376 molecules
# Batch 190: processed 782336 molecules
# Batch 200: processed 823296 molecules
# Batch 210: processed 864256 molecules
# Batch 220: processed 905216 molecules
# Batch 230: processed 946176 molecules
# Batch 240: processed 987136 molecules
# Batch 250: processed 1028096 molecules
# Batch 260: processed 1069056 molecules
# Batch 270: processed 1110016 molecules
# Batch 280: processed 1150976 molecules
# Batch 290: processed 1191936 molecules
# Batch 300: processed 1232896 molecules
# Batch 310: processed 1273856 molecules
# Batch 320: processed 1314816 molecules
# Batch 330: processed 1355776 molecules
# Batch 340: processed 1396736 molecules
# Batch 350: processed 1437696 molecules
# Batch 360: processed 1478656 molecules
# Batch 370: processed 1519616 molecules
# Batch 380: processed 1560576 molecules
# Batch 390: processed 1601536 molecules
# Batch 400: processed 1642496 molecules
# Batch 410: processed 1683456 molecules
# Batch 420: processed 1724416 molecules
# Batch 430: processed 1765376 molecules
# Batch 440: processed 1806336 molecules
# Batch 450: processed 1847296 molecules
# Batch 460: processed 1888256 molecules
# Batch 470: processed 1929216 molecules
# Batch 480: processed 1970176 molecules
# Batch 490: processed 2011136 molecules
# Batch 500: processed 2052096 molecules
# Batch 510: processed 2093056 molecules
# Batch 520: processed 2134016 molecules
# Batch 530: processed 2174976 molecules
# Batch 540: processed 2215936 molecules
# Batch 550: processed 2256896 molecules
# Batch 560: processed 2297856 molecules
# Batch 570: processed 2338816 molecules
# Batch 580: processed 2379776 molecules
# Batch 590: processed 2420736 molecules
# Batch 600: processed 2461696 molecules
# Batch 610: processed 2502656 molecules
# Batch 620: processed 2543616 molecules
# Batch 630: processed 2584576 molecules
# Batch 640: processed 2625536 molecules
# Batch 650: processed 2666496 molecules
# Batch 660: processed 2707456 molecules
# Batch 670: processed 2748416 molecules
# Batch 680: processed 2789376 molecules
# Batch 690: processed 2830336 molecules
# Batch 700: processed 2871296 molecules
# Batch 710: processed 2912256 molecules
# Batch 720: processed 2953216 molecules
# Batch 730: processed 2994176 molecules
# Batch 740: processed 3035136 molecules
# Batch 750: processed 3076096 molecules
# Batch 760: processed 3117056 molecules
# Batch 770: processed 3158016 molecules
# Batch 780: processed 3198976 molecules
# Batch 790: processed 3239936 molecules
# Batch 800: processed 3280896 molecules
# Batch 810: processed 3321856 molecules
# Batch 820: processed 3362816 molecules
# Batch 830: processed 3403776 molecules
# Batch 840: processed 3444736 molecules
# Batch 850: processed 3485696 molecules
# Batch 860: processed 3526656 molecules
# Batch 870: processed 3567616 molecules
# Batch 880: processed 3608576 molecules
# Batch 890: processed 3649536 molecules
# Batch 900: processed 3690496 molecules
# Batch 910: processed 3731456 molecules
# Batch 920: processed 3772416 molecules
# Batch 930: processed 3813376 molecules
# Batch 940: processed 3854336 molecules
# Batch 950: processed 3895296 molecules
# Batch 960: processed 3936256 molecules
# Batch 970: processed 3977216 molecules
# Batch 980: processed 4018176 molecules
# Batch 990: processed 4059136 molecules
# Batch 1000: processed 4100096 molecules
# Batch 1010: processed 4141056 molecules
# Batch 1020: processed 4182016 molecules
# Batch 1030: processed 4222976 molecules
# Batch 1040: processed 4263936 molecules
# Batch 1050: processed 4304896 molecules
# Batch 1060: processed 4345856 molecules
# Batch 1070: processed 4386816 molecules
# Batch 1080: processed 4427776 molecules
# Batch 1090: processed 4468736 molecules
# Batch 1100: processed 4509696 molecules
# Batch 1110: processed 4550656 molecules
# Batch 1120: processed 4591616 molecules
# Batch 1130: processed 4632576 molecules
# Batch 1140: processed 4673536 molecules
# Batch 1150: processed 4714496 molecules
# Batch 1160: processed 4755456 molecules
# Batch 1170: processed 4796416 molecules
# Batch 1180: processed 4837376 molecules
# Batch 1190: processed 4878336 molecules
# Batch 1200: processed 4919296 molecules
# Batch 1210: processed 4960256 molecules
# Batch 1220: processed 5001216 molecules
# Batch 1230: processed 5042176 molecules
# Batch 1240: processed 5083136 molecules
# Batch 1250: processed 5124096 molecules
# Batch 1260: processed 5165056 molecules
# Batch 1270: processed 5206016 molecules
# Batch 1280: processed 5246976 molecules
# Batch 1290: processed 5287936 molecules
# Batch 1300: processed 5328896 molecules
# Batch 1310: processed 5369856 molecules
# Batch 1320: processed 5410816 molecules
# Batch 1330: processed 5451776 molecules
# Batch 1340: processed 5492736 molecules
# Batch 1350: processed 5533696 molecules
# Batch 1360: processed 5574656 molecules
# Batch 1370: processed 5615616 molecules
# Batch 1380: processed 5656576 molecules
# Batch 1390: processed 5697536 molecules
# Batch 1400: processed 5738496 molecules
# Batch 1410: processed 5779456 molecules
# Batch 1420: processed 5820416 molecules
# Batch 1430: processed 5861376 molecules
# Batch 1440: processed 5902336 molecules
# Batch 1450: processed 5943296 molecules
# Batch 1460: processed 5984256 molecules
# Batch 1470: processed 6025216 molecules
# Batch 1480: processed 6066176 molecules
# Batch 1490: processed 6107136 molecules
# Batch 1500: processed 6148096 molecules
# Batch 1510: processed 6189056 molecules
# Batch 1520: processed 6230016 molecules
# Batch 1530: processed 6270976 molecules
# Batch 1540: processed 6311936 molecules
# Batch 1550: processed 6352896 molecules
# Batch 1560: processed 6393856 molecules
# Batch 1570: processed 6434816 molecules
# Batch 1580: processed 6475776 molecules
# Batch 1590: processed 6516736 molecules
# Batch 1600: processed 6557696 molecules
# Batch 1610: processed 6598656 molecules
# Batch 1620: processed 6639616 molecules
# Batch 1630: processed 6680576 molecules
# Batch 1640: processed 6721536 molecules
# Batch 1650: processed 6762496 molecules
# Batch 1660: processed 6803456 molecules
# Batch 1670: processed 6844416 molecules
# Batch 1680: processed 6885376 molecules
# Batch 1690: processed 6926336 molecules
# Batch 1700: processed 6967296 molecules
# Batch 1710: processed 7008256 molecules
# Batch 1720: processed 7049216 molecules
# Batch 1730: processed 7090176 molecules
# Batch 1740: processed 7131136 molecules
# Batch 1750: processed 7172096 molecules
# Batch 1760: processed 7213056 molecules
# Batch 1770: processed 7254016 molecules
# Batch 1780: processed 7294976 molecules
# Batch 1790: processed 7335936 molecules
# Batch 1800: processed 7376896 molecules
# Batch 1810: processed 7417856 molecules
# Batch 1820: processed 7458816 molecules
# Batch 1830: processed 7499776 molecules
# Batch 1840: processed 7540736 molecules
# Batch 1850: processed 7581696 molecules
# Batch 1860: processed 7622656 molecules
# Batch 1870: processed 7663616 molecules
# Batch 1880: processed 7704576 molecules
# Batch 1890: processed 7745536 molecules
# Batch 1900: processed 7786496 molecules
# Batch 1910: processed 7827456 molecules
# Batch 1920: processed 7868416 molecules
# Batch 1930: processed 7909376 molecules
# Batch 1940: processed 7950336 molecules
# Batch 1950: processed 7991296 molecules
# Batch 1960: processed 8032256 molecules
# Batch 1970: processed 8073216 molecules
# Batch 1980: processed 8114176 molecules
# Batch 1990: processed 8155136 molecules
# Batch 2000: processed 8196096 molecules
# Batch 2010: processed 8237056 molecules
# Batch 2020: processed 8278016 molecules
# Batch 2030: processed 8318976 molecules
# Batch 2040: processed 8359936 molecules
# Batch 2050: processed 8400896 molecules
# Batch 2060: processed 8441856 molecules
# Batch 2070: processed 8482816 molecules
# Batch 2080: processed 8523776 molecules
# Batch 2090: processed 8564736 molecules
# Batch 2100: processed 8605696 molecules
# Batch 2110: processed 8646656 molecules
# Batch 2120: processed 8687616 molecules
# Batch 2130: processed 8728576 molecules
# Batch 2140: processed 8769536 molecules
# Batch 2150: processed 8810496 molecules
# Batch 2160: processed 8851456 molecules
# Batch 2170: processed 8892416 molecules
# Batch 2180: processed 8933376 molecules
# Batch 2190: processed 8974336 molecules
# Batch 2200: processed 9015296 molecules
# Batch 2210: processed 9056256 molecules
# Batch 2220: processed 9097216 molecules
# Batch 2230: processed 9138176 molecules
# Batch 2240: processed 9179136 molecules
# Batch 2250: processed 9220096 molecules
# Batch 2260: processed 9261056 molecules
# Batch 2270: processed 9302016 molecules
# Batch 2280: processed 9342976 molecules
# Batch 2290: processed 9383936 molecules
# Batch 2300: processed 9424896 molecules
# Batch 2310: processed 9465856 molecules
# Batch 2320: processed 9506816 molecules
# Batch 2330: processed 9547776 molecules
# Batch 2340: processed 9588736 molecules
# Batch 2350: processed 9629696 molecules
# Batch 2360: processed 9670656 molecules
# Batch 2370: processed 9711616 molecules
# Batch 2380: processed 9752576 molecules
# Batch 2390: processed 9793536 molecules
# Batch 2400: processed 9834496 molecules
# Batch 2410: processed 9875456 molecules
# Batch 2420: processed 9916416 molecules
# Batch 2430: processed 9957376 molecules
# Batch 2440: processed 9998336 molecules
# Batch 2450: processed 10039296 molecules
# Batch 2460: processed 10080256 molecules
# Batch 2470: processed 10121216 molecules
# Batch 2480: processed 10162176 molecules
# Batch 2490: processed 10203136 molecules
# Batch 2500: processed 10244096 molecules
# Batch 2510: processed 10285056 molecules
# Batch 2520: processed 10326016 molecules
# Batch 2530: processed 10366976 molecules
# Batch 2540: processed 10407936 molecules
# Batch 2550: processed 10448896 molecules
# Batch 2560: processed 10489856 molecules
# Batch 2570: processed 10530816 molecules
# Batch 2580: processed 10571776 molecules
# Batch 2590: processed 10612736 molecules
# Batch 2600: processed 10653696 molecules
# Batch 2610: processed 10694656 molecules
# Batch 2620: processed 10735616 molecules
# Batch 2630: processed 10776576 molecules
# Batch 2640: processed 10817536 molecules
# Batch 2650: processed 10858496 molecules
# Batch 2660: processed 10899456 molecules
# Batch 2670: processed 10940416 molecules
# Batch 2680: processed 10981376 molecules
# Batch 2690: processed 11022336 molecules
# Batch 2700: processed 11063296 molecules
# Batch 2710: processed 11104256 molecules
# Batch 2720: processed 11145216 molecules
# Batch 2730: processed 11186176 molecules
# Batch 2740: processed 11227136 molecules
# Batch 2750: processed 11268096 molecules
# Batch 2760: processed 11309056 molecules
# Batch 2770: processed 11350016 molecules
# Batch 2780: processed 11390976 molecules
# Batch 2790: processed 11431936 molecules
# Batch 2800: processed 11472896 molecules
# Batch 2810: processed 11513856 molecules
# Batch 2820: processed 11554816 molecules
# Batch 2830: processed 11595776 molecules
# Batch 2840: processed 11636736 molecules
# Batch 2850: processed 11677696 molecules
# Batch 2860: processed 11718656 molecules
# Batch 2870: processed 11759616 molecules
# Batch 2880: processed 11800576 molecules
# Batch 2890: processed 11841536 molecules
# Batch 2900: processed 11882496 molecules
# Batch 2910: processed 11923456 molecules
# Batch 2920: processed 11964416 molecules
# Batch 2930: processed 12005376 molecules
# Batch 2940: processed 12046336 molecules
# Batch 2950: processed 12087296 molecules
# Batch 2960: processed 12128256 molecules
# Batch 2970: processed 12169216 molecules
# Batch 2980: processed 12210176 molecules
# Batch 2990: processed 12251136 molecules
# Batch 3000: processed 12292096 molecules
# Batch 3010: processed 12333056 molecules
# Batch 3020: processed 12374016 molecules
# Batch 3030: processed 12414976 molecules
# Batch 3040: processed 12455936 molecules
# Batch 3050: processed 12496896 molecules
# Batch 3060: processed 12537856 molecules
# Batch 3070: processed 12578816 molecules
# Batch 3080: processed 12619776 molecules
# Batch 3090: processed 12660736 molecules
# Batch 3100: processed 12701696 molecules
# Batch 3110: processed 12742656 molecules
# Batch 3120: processed 12783616 molecules
# Batch 3130: processed 12824576 molecules
# Batch 3140: processed 12865536 molecules
# Batch 3150: processed 12906496 molecules
# Batch 3160: processed 12947456 molecules
# Batch 3170: processed 12988416 molecules
# Batch 3180: processed 13029376 molecules
# Batch 3190: processed 13070336 molecules
# Batch 3200: processed 13111296 molecules
# Batch 3210: processed 13152256 molecules
# Batch 3220: processed 13193216 molecules
# Batch 3230: processed 13234176 molecules
# Batch 3240: processed 13275136 molecules
# Batch 3250: processed 13316096 molecules
# Batch 3260: processed 13357056 molecules
# Batch 3270: processed 13398016 molecules
# Batch 3280: processed 13438976 molecules
# Batch 3290: processed 13479936 molecules
# Batch 3300: processed 13520896 molecules
# Batch 3310: processed 13561856 molecules
# Batch 3320: processed 13602816 molecules
# Batch 3330: processed 13643776 molecules
# Batch 3340: processed 13684736 molecules
# Batch 3350: processed 13725696 molecules
# Batch 3360: processed 13766656 molecules
# Batch 3370: processed 13807616 molecules
# Batch 3380: processed 13848576 molecules
# Batch 3390: processed 13889536 molecules
# Batch 3400: processed 13930496 molecules
# Batch 3410: processed 13971456 molecules
# Batch 3420: processed 14012416 molecules
# Batch 3430: processed 14053376 molecules
# Batch 3440: processed 14094336 molecules
# Batch 3450: processed 14135296 molecules
# Batch 3460: processed 14176256 molecules
# Batch 3470: processed 14217216 molecules
# Batch 3480: processed 14258176 molecules
# Batch 3490: processed 14299136 molecules
# Batch 3500: processed 14340096 molecules
# Batch 3510: processed 14381056 molecules
# Batch 3520: processed 14422016 molecules
# Batch 3530: processed 14462976 molecules
# Batch 3540: processed 14503936 molecules
# Batch 3550: processed 14544896 molecules
# Batch 3560: processed 14585856 molecules
# Batch 3570: processed 14626816 molecules
# Batch 3580: processed 14667776 molecules
# Batch 3590: processed 14708736 molecules
# Batch 3600: processed 14749696 molecules
# Batch 3610: processed 14790656 molecules
# Batch 3620: processed 14831616 molecules
# Batch 3630: processed 14872576 molecules
# Batch 3640: processed 14913536 molecules
# Batch 3650: processed 14954496 molecules
# Batch 3660: processed 14995456 molecules
# Batch 3670: processed 15036416 molecules
# Batch 3680: processed 15077376 molecules
# Batch 3690: processed 15118336 molecules
# Batch 3700: processed 15159296 molecules
# Batch 3710: processed 15200256 molecules
# Batch 3720: processed 15241216 molecules
# Batch 3730: processed 15282176 molecules
# Batch 3740: processed 15323136 molecules
# Batch 3750: processed 15364096 molecules
# Batch 3760: processed 15405056 molecules
# Batch 3770: processed 15446016 molecules
# Batch 3780: processed 15486976 molecules
# Batch 3790: processed 15527936 molecules
# Batch 3800: processed 15568896 molecules
# Batch 3810: processed 15609856 molecules
# Batch 3820: processed 15650816 molecules
# Batch 3830: processed 15691776 molecules
# Batch 3840: processed 15732736 molecules
# Batch 3850: processed 15773696 molecules
# Batch 3860: processed 15814656 molecules
# Batch 3870: processed 15855616 molecules
# Batch 3880: processed 15896576 molecules
# Batch 3890: processed 15937536 molecules
# Batch 3900: processed 15978496 molecules
# Batch 3910: processed 16019456 molecules
# Batch 3920: processed 16060416 molecules
# Batch 3930: processed 16101376 molecules
# Batch 3940: processed 16142336 molecules
# Batch 3950: processed 16183296 molecules
# Batch 3960: processed 16224256 molecules
# Batch 3970: processed 16265216 molecules
# Batch 3980: processed 16306176 molecules
# Batch 3990: processed 16347136 molecules
# Batch 4000: processed 16388096 molecules
#
# Top 10 6-halogenated molecules:
#  1. Imin = 341.97 → ['H', 'F', 'F', 'H', 'H', 'H', 'F', 'H', 'H', 'F', 'H', 'H', 'H', 'F', 'F', 'H']
#  2. Imin = 342.17 → ['H', 'F', 'F', 'H', 'F', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'F', 'F', 'H']
#  3. Imin = 342.17 → ['H', 'F', 'F', 'H', 'H', 'H', 'F', 'F', 'H', 'H', 'H', 'H', 'H', 'F', 'F', 'H']
#  4. Imin = 342.19 → ['H', 'F', 'F', 'F', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'F', 'F', 'H']
#  5. Imin = 342.29 → ['H', 'F', 'F', 'H', 'H', 'F', 'H', 'H', 'H', 'F', 'H', 'H', 'H', 'F', 'F', 'H']
#  6. Imin = 342.33 → ['H', 'F', 'F', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'F', 'F', 'H']
#  7. Imin = 342.47 → ['H', 'F', 'F', 'H', 'F', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'F', 'H']
#  8. Imin = 342.50 → ['H', 'F', 'F', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'F', 'F', 'H']
#  9. Imin = 342.52 → ['H', 'F', 'F', 'H', 'F', 'H', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'F', 'F', 'H']
# 10. Imin = 342.53 → ['H', 'F', 'F', 'H', 'H', 'F', 'H', 'H', 'H', 'H', 'F', 'H', 'H', 'F', 'F', 'H']
#
#  Finished: 16402176 molecules in 1049.29 s

# %%
# Step 1: group predictions by number of halogen substitutions
substitution_levels = {
    1: mono_predictions,
    2: di_predictions,
    3: tri_predictions,
    4: tetra_predictions,
    5: penta_predictions,
    6: hexa_predictions
}

top_n = 100
avg_imin = []
std_err_imin = []
labels = []

for n_subs in sorted(substitution_levels.keys()):
    preds = substitution_levels[n_subs]

    # Sort by Imin in descending order
    sorted_preds = sorted(preds, key=lambda x: x[1], reverse=False)

    # Take the top_n best molecules
    top_preds = sorted_preds[:top_n]

    # Calculate mean and standard error
    imin_values = [imin for _, imin in top_preds]
    mean = np.mean(imin_values)
    stderr = np.std(imin_values, ddof=1) / np.sqrt(len(imin_values))

    avg_imin.append(mean)
    std_err_imin.append(stderr)
    labels.append(n_subs)

# Step 2: plotting
plt.figure(figsize=(8, 5))
plt.errorbar(labels, avg_imin, yerr=std_err_imin, fmt='o-', color='blue', capsize=5, label='Top 100 avg')
plt.xlabel('Number of Substituents')
plt.ylabel('Predicted $I_{min}$ / cgs')
plt.title('Average $I_{min}$ of Top 100 Molecules by Substitution Level')
plt.xticks(labels)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data analysis for hepta to hexadeca-halogenated [6]Helicenes
# We are just going to predict 100 random molecules for each substituent from 7 to 16 due to the lack of power to predict all the molecules. This will lead us to an abrupt downfall of the Imin mean curve from the 7th substituent because we cant make the mean value with the top 100 molecules.

# %%
import random

def generate_random_n_halogenated_helicenes(n_subs, n_samples=100, seed=42):
    random.seed(seed + n_subs)
    np.random.seed(seed + n_subs)
    seen = set()
    molecules = []
    attempts = 0
    min_attempts = n_samples * 100
    while len(molecules) < n_samples and attempts < min_attempts:
        pos_comb = random.sample(positions, n_subs)
        hal_comb = [random.choice(halogens) for _ in range(n_subs)]
        molecule = ['H'] * 16
        for pos, hal in zip(pos_comb, hal_comb):
            molecule[pos - 1] = hal
        mol_tuple = tuple(molecule)
        mol_rev = tuple(molecule[::-1])
        if mol_tuple in seen or mol_rev in seen:
            attempts += 1
            continue
        seen.add(mol_tuple)
        molecules.append(molecule)
        attempts += 1
    return molecules

# Store all predictions for each substituent count in separate variables
hepta_predictions = []
octa_predictions = []
nona_predictions = []
deca_predictions = []
undeca_predictions = []
dodeca_predictions = []
trideca_predictions = []
tetradeca_predictions = []
pentadeca_predictions = []
hexadeca_predictions = []

for n_subs in range(7, 17):
    random_mols = generate_random_n_halogenated_helicenes(n_subs=n_subs, n_samples=100, seed=42)
    encoded_batch = np.vstack([encode_molecule(mol, n_pos=16, n_atom_types=5) for mol in random_mols])
    pred_norm = best_model.predict(encoded_batch, verbose=0)
    pred = pred_norm * Imin_abs_std + Imin_abs_mean
    predictions = [(mol, float(val)) for mol, val in zip(random_mols, pred.ravel())]
    if n_subs == 7:
        hepta_predictions = predictions
    elif n_subs == 8:
        octa_predictions = predictions
    elif n_subs == 9:
        nona_predictions = predictions
    elif n_subs == 10:
        deca_predictions = predictions
    elif n_subs == 11:
        undeca_predictions = predictions
    elif n_subs == 12:
        dodeca_predictions = predictions
    elif n_subs == 13:
        trideca_predictions = predictions
    elif n_subs == 14:
        tetradeca_predictions = predictions
    elif n_subs == 15:
        pentadeca_predictions = predictions
    elif n_subs == 16:
        hexadeca_predictions = predictions
    print(f"Stored {len(predictions)} predictions for {n_subs}-halogenated [6]Helicenes.")
# Out:
# Stored 100 predictions for 7-halogenated [6]Helicenes.
# Stored 100 predictions for 8-halogenated [6]Helicenes.
# Stored 100 predictions for 9-halogenated [6]Helicenes.
# Stored 100 predictions for 10-halogenated [6]Helicenes.
# Stored 100 predictions for 11-halogenated [6]Helicenes.
# Stored 100 predictions for 12-halogenated [6]Helicenes.
# Stored 100 predictions for 13-halogenated [6]Helicenes.
# Stored 100 predictions for 14-halogenated [6]Helicenes.
# Stored 100 predictions for 15-halogenated [6]Helicenes.
# Stored 100 predictions for 16-halogenated [6]Helicenes.

# %%
# 1) Load the GA‐derived CSV for n = 7…16
df_top100 = pd.read_csv('ga_top100_Imin_n7_16.csv')

# 2) Compute mean_imin and full_widths for n = 1..16
mean_imin   = []
full_widths = []
labels      = list(range(1, 17))

# 2A) n = 1..6 (brute‐force lists)
for n_subs, preds in zip(
    range(1, 7),
    [mono_predictions, di_predictions, tri_predictions, tetra_predictions, penta_predictions, hexa_predictions]
):
    # sort in ascending order to pick the 100 smallest R values
    top_preds = sorted(preds, key=lambda x: x[1])[:100]
    imin_vals = [r for (_, r) in top_preds]
    mean_val  = np.mean(imin_vals)

    molecules = [mol for (mol, _) in top_preds]
    encoded   = np.vstack([
        encode_molecule(mol, n_pos=16, n_atom_types=5)
        for mol in molecules
    ])
    lower_real = (model_lower.predict(encoded, verbose=0).ravel()
                  * Imin_abs_std + Imin_abs_mean)
    upper_real = (model_upper.predict(encoded, verbose=0).ravel()
                  * Imin_abs_std + Imin_abs_mean)

    lower_real = np.maximum(lower_real, 0)

    width = np.mean(upper_real - lower_real)

    mean_imin.append(mean_val)
    full_widths.append(width)

# 2B) n = 7..16 (GA‐derived)
for n_subs in range(7, 17):
    df_n       = df_top100[df_top100['n_subs'] == n_subs]
    mu_real    = df_n['mu_real'].values
    sigma_real = df_n['sigma_real'].values

    mean_val = mu_real.mean()
    width    = 2.0 * sigma_real.mean()

    mean_imin.append(mean_val)
    full_widths.append(width)

# 3) Plotting:
plt.rcParams['font.family']    = 'DejaVu Sans'
plt.rcParams['font.size']      = 10
plt.rcParams['axes.labelsize'] = 11
plt.rcParams['axes.titlesize'] = 12

fig, ax = plt.subplots(figsize=(8, 5), facecolor='white')
ax.set_facecolor('white')

# b) Plot n = 1..6 with circle markers (solid) + error bars
ax.errorbar(
    labels[:6],
    mean_imin[:6],
    yerr=np.array(full_widths[:6]) * 0.5,
    fmt='o-',
    color='tab:blue',
    ecolor='tab:blue',
    elinewidth=1.0,
    capsize=3,
    markerfacecolor='white',
    markeredgewidth=1.3,
    markersize=6,
    linewidth=1.6,
    label='_nolegend_'
)

# c) Plot n = 7..16 with square markers (dashed) + error bars
ax.errorbar(
    labels[6:],
    mean_imin[6:],
    yerr=np.array(full_widths[6:]) * 0.5,
    fmt='s--',
    color='tab:orange',
    ecolor='tab:orange',
    elinewidth=1.0,
    capsize=3,
    markerfacecolor='white',
    markeredgewidth=1.3,
    markersize=6,
    linewidth=1.6,
    label='_nolegend_'
)

# d) Dotted connector between n = 6 and n = 7
ax.plot(
    [6, 7],
    [mean_imin[5], mean_imin[6]],
    linestyle=':',
    color='gray',
    linewidth=1.2,
    zorder=3
)

# e) Axis labels and title (updated for R_min)
ax.set_xlabel('Number of Substituents', fontsize=11, labelpad=6)
ax.set_ylabel(r'Predicted $I_{\min}$ / cgs', fontsize=11, labelpad=6)
ax.set_title('Average $I_{\min}$ of Top 100 Molecules by Substitution Level', fontsize=12, pad=10)

# f) Ticks, grid, and updated y-limit
ax.set_xticks(labels)
ax.set_xticklabels(labels)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlim(0.5, 16.5)
ax.set_ylim(bottom=330)
ax.grid(linestyle='--', alpha=0.5, color='lightgray')

# g) Ensure all spines are visible and styled
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color('black')
    spine.set_linewidth(0.8)

plt.tight_layout()
plt.show()

# %%
# Step 1: group predictions by number of halogen substitutions
substitution_levels = {
    1: mono_predictions,
    2: di_predictions,
    3: tri_predictions,
    4: tetra_predictions,
    5: penta_predictions,
    6: hexa_predictions,
    7: hepta_predictions,
    8: octa_predictions,
    9: nona_predictions,
    10: deca_predictions,
    11: undeca_predictions,
    12: dodeca_predictions,
    13: trideca_predictions,
    14: tetradeca_predictions,
    15: pentadeca_predictions,
    16: hexadeca_predictions
}

top_n = 100
avg_imin = []
std_err_imin = []
labels = []

for n_subs in sorted(substitution_levels.keys()):
    preds = substitution_levels[n_subs]

    # Sort by Imin in descending order
    sorted_preds = sorted(preds, key=lambda x: x[1], reverse=False)

    # Take the top_n best molecules
    top_preds = sorted_preds[:top_n]

    # Calculate mean and standard error
    imin_values = [imin for _, imin in top_preds]
    mean = np.mean(imin_values)
    stderr = np.std(imin_values, ddof=1) / np.sqrt(len(imin_values))

    avg_imin.append(mean)
    std_err_imin.append(stderr)
    labels.append(n_subs)

plt.figure(figsize=(8, 5))

# Plot 1-6 substituents as a solid line
plt.plot(labels[:6], avg_imin[:6], 'o-', color='blue', label='Top 100 avg (1-6)', linestyle='-')

# Plot 7-16 substituents as a dashed line
plt.plot(labels[6:], avg_imin[6:], 'o--', color='blue', label='Top 100 avg (7-16)', linestyle='--')

# Connect point 6 to 7 with a line
plt.plot([labels[5], labels[6]], [avg_imin[5], avg_imin[6]], color='blue', linestyle=':', linewidth=2)

plt.xlabel('Number of Substituents')
plt.ylabel('Predicted $I_{min}$ / cgs')
plt.title('Average $I_{min}$ of Top 100 Molecules by Substitution Level')
plt.xticks(labels)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\AlejandroN01\AppData\Local\Temp\ipykernel_27012\415662873.py:47: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(labels[:6], avg_imin[:6], 'o-', color='blue', label='Top 100 avg (1-6)', linestyle='-')
# C:\Users\AlejandroN01\AppData\Local\Temp\ipykernel_27012\415662873.py:50: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o--" (-> linestyle='--'). The keyword argument will take precedence.
#   plt.plot(labels[6:], avg_imin[6:], 'o--', color='blue', label='Top 100 avg (7-16)', linestyle='--')

# %%
# Initialize accumulators
mean_imin = []
intervals = []
labels = []

# 1-6 substituents: mean and quantile interval
for n_subs, preds in zip(range(1, 7), [mono_predictions, di_predictions, tri_predictions, tetra_predictions, penta_predictions, hexa_predictions]):
    top_preds = sorted(preds, key=lambda x: x[1], reverse=False)[:100]
    molecules = [mol for mol, _ in top_preds]
    encoded = np.vstack([encode_molecule(mol, n_pos=16, n_atom_types=5) for mol in molecules])
    lower_norm = model_lower.predict(encoded, verbose=0).ravel()
    upper_norm = model_upper.predict(encoded, verbose=0).ravel()
    lower = lower_norm * Imin_abs_std + Imin_abs_mean
    upper = upper_norm * Imin_abs_std + Imin_abs_mean
    interval = np.mean(upper - lower)
    mean = np.mean([imin for _, imin in top_preds])
    mean_imin.append(mean)
    intervals.append(interval)
    labels.append(n_subs)

# 7-16 substituents: only mean, no error bar
mean_imin_7_16 = []
labels_7_16 = []
for n_subs, preds in zip(
    range(7, 17),
    [hepta_predictions, octa_predictions, nona_predictions, deca_predictions, undeca_predictions,
     dodeca_predictions, trideca_predictions, tetradeca_predictions, pentadeca_predictions, hexadeca_predictions]
):
    top_preds = sorted(preds, key=lambda x: x[1], reverse=False)[:100]
    mean = np.mean([imin for _, imin in top_preds])
    mean_imin_7_16.append(mean)
    labels_7_16.append(n_subs)

# Plot 1: 1-6 substituents
plt.figure(figsize=(7, 4))
plt.errorbar(labels, mean_imin, yerr=intervals, fmt='o-', color='blue', capsize=5, label='Top 100 avg (1-6)')
plt.xlabel('Number of Substituents')
plt.ylabel('Predicted $I_{min}$ / cgs')
plt.xticks(labels)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# Plot 2: 7-16 substituents
plt.figure(figsize=(7, 4))
plt.plot(labels_7_16, mean_imin_7_16, 'o--', color='blue', label='100 random avg (7-16)')
plt.xlabel('Number of Substituents')
plt.ylabel('Predicted $I_{min}$ / cgs')
plt.xticks(labels_7_16)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# --- Combined plot: Mean Imin (top 100) with quantile interval as error bar for 1-6 substituents ---

mean_imin= []
intervals = []
labels = []

# 1-6 substituents: mean and quantile interval
for n_subs, preds in zip(range(1, 7), [mono_predictions, di_predictions, tri_predictions, tetra_predictions, penta_predictions, hexa_predictions]):
    top_preds = sorted(preds, key=lambda x: x[1], reverse=False)[:100]
    molecules = [mol for mol, _ in top_preds]
    encoded = np.vstack([encode_molecule(mol, n_pos=16, n_atom_types=5) for mol in molecules])
    lower_norm = model_lower.predict(encoded, verbose=0).ravel()
    upper_norm = model_upper.predict(encoded, verbose=0).ravel()
    lower = lower_norm * Imin_abs_std + Imin_abs_mean
    upper = upper_norm * Imin_abs_std + Imin_abs_mean
    interval = np.mean(upper - lower)
    mean = np.mean([imin for _, imin in top_preds])
    mean_imin.append(mean)
    intervals.append(interval)
    labels.append(n_subs)

# 7-16 substituents: only mean, no error bar
for n_subs, preds in zip(
    range(7, 17),
    [hepta_predictions, octa_predictions, nona_predictions, deca_predictions, undeca_predictions,
     dodeca_predictions, trideca_predictions, tetradeca_predictions, pentadeca_predictions, hexadeca_predictions]
):
    top_preds = sorted(preds, key=lambda x: x[1], reverse=False)[:100]
    mean = np.mean([imin for _, imin in top_preds])
    mean_imin.append(mean)
    intervals.append(0)  # No error bar
    labels.append(n_subs)

plt.figure(figsize=(8, 5))
plt.errorbar(labels[:6], mean_imin[:6], yerr=intervals[:6], fmt='o-', color='blue', capsize=5, label='Top 100 avg (1-6)')
plt.plot(labels[6:], mean_imin[6:], 'o--', color='blue', label='100 random avg (7-16)')
# Connect point 6 to 7
plt.plot([labels[5], labels[6]], [mean_imin[5], mean_imin[6]], color='blue', linestyle=':', linewidth=2)
plt.xlabel('Number of Substituents')
plt.ylabel('Predicted $I_{min}$ / cgs')
plt.xticks(labels)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()
